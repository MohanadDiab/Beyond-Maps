# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd /gdrive/My Drive/Thesis_Resources/Use_cases/MDPI_Pollution
# Out:
# /gdrive/My Drive/Thesis_Resources/Use_cases/MDPI_Pollution

# %%
# Install the landsatxplore library
# !pip install landsatxplore

# %%
from landsatxplore.api import API
from landsatxplore.earthexplorer import EarthExplorer

# Your credentials for Earth Explorer
username = 'fatabs'
password = 'itsmeniggah1'

# Initialize the API
api = API(username, password)
ee = EarthExplorer(username, password)

# Define the area of interest (Freetown, Sierra Leone) and date range
latitude = 8.4840
longitude = -13.2299
start_date = '2017-04-29'
end_date = '2017-11-11'

# Search for Landsat scenes
scenes = api.search(
    dataset='landsat_ot_c2_l1',
    latitude=latitude,
    longitude=longitude,
    start_date=start_date,
    end_date=end_date,
    max_cloud_cover=20
)


# Process the result
for scene in scenes:
    print(scene['acquisition_date'].strftime('%Y-%m-%d'))
    # Write scene footprints to disk
    fname = f"{scene['landsat_product_id']}.geojson"

    ee.download(scene["entity_id"], output_dir='./data')




ee.logout()
api.logout()
